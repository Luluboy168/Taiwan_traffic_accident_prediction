# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.utils import class_weight
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import backend as K

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from imblearn.over_sampling import RandomOverSampler
from collections import Counter
# Out:
# 2025-03-17 23:49:10.844976: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-17 23:49:11.079698: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742226551.163493    1948 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742226551.187204    1948 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-17 23:49:11.408311: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def load_data(type, file_type):
    path = f"dataset/{type}/{file_type}.csv"
    df = pd.read_csv(
        path, 
        encoding="utf-8",
        low_memory=False,
        dtype=int)
    
    df["label"] = 1 if file_type == "A1" else 0
    return df

# %%
train_dfs_A1 = load_data("train", "A1")
train_dfs_A2 = load_data("train", "A2")

df_train = pd.concat([train_dfs_A1, train_dfs_A2], ignore_index=True)

df_a1_test = load_data("test", "A1")
df_a2_test = load_data("test", "A2")

# Combine into one DataFrame for testing
df_test = pd.concat([df_a1_test, df_a2_test], ignore_index=True)

# shuffle
df_train = df_train.sample(frac=1, random_state=42)
df_test = df_test.sample(frac=1, random_state=42)

cols = [col for col in df_train.columns if (col != '發生日期' and col != "label")]

df_train = df_train.dropna(how='any')
df_test = df_test.dropna(how='any')

X_train = df_train[cols]
y_train = df_train["label"]

X_test = df_test[cols]
y_test = df_test["label"]

# %%
# Print original class distribution
print("Original distribution:", Counter(y_train))

# Oversample the training data
ros = RandomOverSampler(sampling_strategy='minority')
# X_train, y_train = ros.fit_resample(X_train, y_train)
X_test, y_test = ros.fit_resample(X_test, y_test)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Check the new class distribution
print("Resampled distribution:", Counter(y_train))
# Out:
# Original distribution: Counter({0: 1108672, 1: 7279})
# Resampled distribution: Counter({0: 1108672, 1: 7279})

# %%
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', threshold=0.5, **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.threshold = threshold
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.false_positives = self.add_weight(name='fp', initializer='zeros')
        self.false_negatives = self.add_weight(name='fn', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Convert probabilities to binary predictions
        y_pred = tf.cast(tf.greater(y_pred, self.threshold), tf.float32)
        y_true = tf.cast(y_true, tf.float32)

        tp = tf.reduce_sum(y_true * y_pred)
        fp = tf.reduce_sum((1 - y_true) * y_pred)
        fn = tf.reduce_sum(y_true * (1 - y_pred))

        self.true_positives.assign_add(tp)
        self.false_positives.assign_add(fp)
        self.false_negatives.assign_add(fn)

    def result(self):
        precision = self.true_positives / (self.true_positives + self.false_positives + K.epsilon())
        recall = self.true_positives / (self.true_positives + self.false_negatives + K.epsilon())
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.true_positives.assign(0)
        self.false_positives.assign(0)
        self.false_negatives.assign(0)

# %%
# ------------------------------------------------
# Build a TensorFlow Model
# ------------------------------------------------

model = tf.keras.Sequential([
    # Input layer
    layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # First hidden layer with 128 units
    layers.Dense(128, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # Second hidden layer with 64 units
    layers.Dense(64, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # Third hidden layer with 32 units
    layers.Dense(32, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # Fourth hidden layer with 16 units
    layers.Dense(16, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    # Output layer for binary classification
    layers.Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=[
        # "Accuracy"
        tf.keras.metrics.BinaryAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        F1Score(name='f1_score'),
        tf.keras.metrics.AUC(name='auc', num_thresholds=200)
    ]
)

# ------------------------------------------------
# Train Model
# ------------------------------------------------

history = model.fit(
    X_train, y_train,
    epochs=80,
    batch_size=2048,
    validation_split=0.3,
    verbose=1
)

# ------------------------------------------------
# Evaluate on Test Data from 109 files
# ------------------------------------------------
pred_probs = model.predict(X_test).ravel()
pred_labels = (pred_probs > 0.5).astype(int)

precision = precision_score(y_test, pred_labels)
recall = recall_score(y_test, pred_labels)
f1 = f1_score(y_test, pred_labels)

print("Precision:", precision)
print("Recall:   ", recall)
print("F1 Score: ", f1)

# Optional: detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, pred_labels, target_names=["A2 (Injury)", "A1 (Fatal)"]))
# Out:
# /home/luluboy/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1742226556.482950    1948 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21770 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742226558.901042    2096 service.cc:148] XLA service 0x7fe7c801a380 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742226558.901351    2096 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-03-17 23:49:18.951310: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742226559.162485    2096 cuda_dnn.cc:529] Loaded cuDNN version 90800
#  48/382 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5227 - auc: 0.4967 - f1_score: 0.0123 - loss: 0.7809 - precision: 0.0062 - recall: 0.4820
# I0000 00:00:1742226561.901978    2096 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8059 - auc: 0.4958 - f1_score: 0.0149 - loss: 0.5272 - precision: 0.0078 - recall: 0.2180 - val_accuracy: 0.9934 - val_auc: 0.5276 - val_f1_score: 0.0000e+00 - val_loss: 0.0790 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9931 - auc: 0.4987 - f1_score: 0.0079 - loss: 0.0682 - precision: 0.0509 - recall: 0.0043 - val_accuracy: 0.9934 - val_auc: 0.5238 - val_f1_score: 0.0000e+00 - val_loss: 0.0430 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.5153 - f1_score: 0.0013 - loss: 0.0444 - precision: 0.0219 - recall: 6.4467e-04 - val_accuracy: 0.9934 - val_auc: 0.6068 - val_f1_score: 0.0000e+00 - val_loss: 0.0400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.5775 - f1_score: 0.0016 - loss: 0.0411 - precision: 0.0509 - recall: 7.8998e-04 - val_accuracy: 0.9934 - val_auc: 0.7642 - val_f1_score: 0.0000e+00 - val_loss: 0.0380 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.6683 - f1_score: 7.0191e-04 - loss: 0.0398 - precision: 0.0305 - recall: 3.5507e-04 - val_accuracy: 0.9933 - val_auc: 0.7956 - val_f1_score: 0.0000e+00 - val_loss: 0.0370 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.7127 - f1_score: 6.7452e-05 - loss: 0.0389 - precision: 0.0033 - recall: 3.4074e-05 - val_accuracy: 0.9934 - val_auc: 0.7951 - val_f1_score: 0.0000e+00 - val_loss: 0.0367 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - auc: 0.7346 - f1_score: 2.0412e-04 - loss: 0.0370 - precision: 0.0122 - recall: 1.0293e-04 - val_accuracy: 0.9934 - val_auc: 0.7936 - val_f1_score: 8.9807e-04 - val_loss: 0.0361 - val_precision: 1.0000 - val_recall: 4.4924e-04
# Epoch 8/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.7401 - f1_score: 0.0011 - loss: 0.0368 - precision: 0.0725 - recall: 5.3010e-04 - val_accuracy: 0.9934 - val_auc: 0.7947 - val_f1_score: 8.9767e-04 - val_loss: 0.0353 - val_precision: 0.5000 - val_recall: 4.4924e-04
# Epoch 9/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - auc: 0.7458 - f1_score: 1.5877e-04 - loss: 0.0362 - precision: 0.0093 - recall: 8.0070e-05 - val_accuracy: 0.9934 - val_auc: 0.8025 - val_f1_score: 0.0000e+00 - val_loss: 0.0351 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.7411 - f1_score: 0.0000e+00 - loss: 0.0367 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8017 - val_f1_score: 8.9807e-04 - val_loss: 0.0349 - val_precision: 1.0000 - val_recall: 4.4924e-04
# Epoch 11/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.7522 - f1_score: 3.1584e-04 - loss: 0.0361 - precision: 0.0386 - recall: 1.5857e-04 - val_accuracy: 0.9934 - val_auc: 0.8060 - val_f1_score: 8.9807e-04 - val_loss: 0.0347 - val_precision: 1.0000 - val_recall: 4.4924e-04
# Epoch 12/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.7531 - f1_score: 8.3275e-04 - loss: 0.0360 - precision: 0.1122 - recall: 4.1806e-04 - val_accuracy: 0.9934 - val_auc: 0.8090 - val_f1_score: 0.0000e+00 - val_loss: 0.0348 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.7731 - f1_score: 0.0000e+00 - loss: 0.0357 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9933 - val_auc: 0.8096 - val_f1_score: 0.0000e+00 - val_loss: 0.0346 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - auc: 0.7724 - f1_score: 6.3616e-04 - loss: 0.0352 - precision: 0.2452 - recall: 3.1851e-04 - val_accuracy: 0.9934 - val_auc: 0.8039 - val_f1_score: 0.0000e+00 - val_loss: 0.0346 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.7669 - f1_score: 0.0000e+00 - loss: 0.0357 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8070 - val_f1_score: 0.0000e+00 - val_loss: 0.0345 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.7741 - f1_score: 0.0018 - loss: 0.0355 - precision: 0.3395 - recall: 9.0481e-04 - val_accuracy: 0.9934 - val_auc: 0.8048 - val_f1_score: 0.0000e+00 - val_loss: 0.0345 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.7774 - f1_score: 0.0012 - loss: 0.0354 - precision: 0.5135 - recall: 6.0473e-04 - val_accuracy: 0.9934 - val_auc: 0.8000 - val_f1_score: 0.0000e+00 - val_loss: 0.0344 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.7721 - f1_score: 2.0214e-04 - loss: 0.0354 - precision: 0.0525 - recall: 1.0127e-04 - val_accuracy: 0.9933 - val_auc: 0.8081 - val_f1_score: 0.0000e+00 - val_loss: 0.0343 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.7744 - f1_score: 0.0000e+00 - loss: 0.0350 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8083 - val_f1_score: 0.0000e+00 - val_loss: 0.0344 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.7833 - f1_score: 0.0012 - loss: 0.0349 - precision: 0.3312 - recall: 5.8695e-04 - val_accuracy: 0.9934 - val_auc: 0.8144 - val_f1_score: 0.0000e+00 - val_loss: 0.0341 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.7852 - f1_score: 0.0011 - loss: 0.0351 - precision: 0.5869 - recall: 5.5577e-04 - val_accuracy: 0.9934 - val_auc: 0.8071 - val_f1_score: 0.0000e+00 - val_loss: 0.0343 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9936 - auc: 0.7812 - f1_score: 0.0014 - loss: 0.0345 - precision: 0.3122 - recall: 7.1178e-04 - val_accuracy: 0.9934 - val_auc: 0.8107 - val_f1_score: 0.0000e+00 - val_loss: 0.0342 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.7760 - f1_score: 4.1313e-06 - loss: 0.0352 - precision: 0.0012 - recall: 2.0693e-06 - val_accuracy: 0.9934 - val_auc: 0.8180 - val_f1_score: 0.0000e+00 - val_loss: 0.0340 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.7844 - f1_score: 0.0000e+00 - loss: 0.0343 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8068 - val_f1_score: 0.0000e+00 - val_loss: 0.0341 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.7834 - f1_score: 0.0042 - loss: 0.0351 - precision: 0.9922 - recall: 0.0021 - val_accuracy: 0.9934 - val_auc: 0.8194 - val_f1_score: 0.0000e+00 - val_loss: 0.0341 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.7956 - f1_score: 0.0000e+00 - loss: 0.0347 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8130 - val_f1_score: 0.0000e+00 - val_loss: 0.0341 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.7879 - f1_score: 8.9049e-04 - loss: 0.0342 - precision: 0.3407 - recall: 4.4586e-04 - val_accuracy: 0.9934 - val_auc: 0.8197 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.7968 - f1_score: 0.0000e+00 - loss: 0.0341 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8172 - val_f1_score: 0.0000e+00 - val_loss: 0.0340 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.7942 - f1_score: 1.2587e-04 - loss: 0.0346 - precision: 0.0548 - recall: 6.3006e-05 - val_accuracy: 0.9934 - val_auc: 0.8126 - val_f1_score: 0.0000e+00 - val_loss: 0.0341 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.7954 - f1_score: 0.0000e+00 - loss: 0.0338 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9933 - val_auc: 0.8171 - val_f1_score: 0.0000e+00 - val_loss: 0.0340 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - auc: 0.7961 - f1_score: 0.0000e+00 - loss: 0.0335 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8146 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.8026 - f1_score: 0.0000e+00 - loss: 0.0346 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8255 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - auc: 0.7974 - f1_score: 4.4303e-04 - loss: 0.0336 - precision: 0.2194 - recall: 2.2175e-04 - val_accuracy: 0.9934 - val_auc: 0.8184 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8087 - f1_score: 4.1446e-04 - loss: 0.0340 - precision: 0.2341 - recall: 2.0742e-04 - val_accuracy: 0.9934 - val_auc: 0.8206 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8051 - f1_score: 0.0000e+00 - loss: 0.0338 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8227 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - auc: 0.8036 - f1_score: 0.0000e+00 - loss: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8170 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8007 - f1_score: 0.0000e+00 - loss: 0.0339 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9933 - val_auc: 0.8200 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.7967 - f1_score: 0.0000e+00 - loss: 0.0339 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8139 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9936 - auc: 0.7967 - f1_score: 1.0428e-04 - loss: 0.0338 - precision: 0.0590 - recall: 5.2189e-05 - val_accuracy: 0.9934 - val_auc: 0.8118 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8103 - f1_score: 0.0013 - loss: 0.0334 - precision: 0.4634 - recall: 6.3364e-04 - val_accuracy: 0.9934 - val_auc: 0.8189 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.7973 - f1_score: 1.1101e-04 - loss: 0.0338 - precision: 0.0568 - recall: 5.5561e-05 - val_accuracy: 0.9934 - val_auc: 0.8188 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8015 - f1_score: 0.0000e+00 - loss: 0.0336 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8091 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.8061 - f1_score: 2.8475e-04 - loss: 0.0340 - precision: 0.1276 - recall: 1.4254e-04 - val_accuracy: 0.9934 - val_auc: 0.8135 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9935 - auc: 0.8050 - f1_score: 7.4376e-05 - loss: 0.0339 - precision: 0.0375 - recall: 3.7225e-05 - val_accuracy: 0.9934 - val_auc: 0.8184 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8044 - f1_score: 0.0000e+00 - loss: 0.0339 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8087 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8087 - f1_score: 0.0000e+00 - loss: 0.0337 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8211 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9937 - auc: 0.8097 - f1_score: 0.0016 - loss: 0.0328 - precision: 0.6276 - recall: 8.0541e-04 - val_accuracy: 0.9934 - val_auc: 0.8212 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8060 - f1_score: 2.8262e-04 - loss: 0.0336 - precision: 0.5117 - recall: 1.4135e-04 - val_accuracy: 0.9934 - val_auc: 0.8115 - val_f1_score: 0.0000e+00 - val_loss: 0.0339 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - auc: 0.8028 - f1_score: 0.0000e+00 - loss: 0.0328 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8175 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8035 - f1_score: 0.0010 - loss: 0.0336 - precision: 0.4822 - recall: 5.0367e-04 - val_accuracy: 0.9934 - val_auc: 0.8239 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 51/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8068 - f1_score: 1.7870e-05 - loss: 0.0332 - precision: 0.0222 - recall: 8.9384e-06 - val_accuracy: 0.9934 - val_auc: 0.8133 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 52/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8089 - f1_score: 0.0000e+00 - loss: 0.0333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8173 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 53/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8022 - f1_score: 0.0017 - loss: 0.0335 - precision: 0.4372 - recall: 8.4515e-04 - val_accuracy: 0.9934 - val_auc: 0.8186 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 54/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.8168 - f1_score: 0.0011 - loss: 0.0338 - precision: 0.4231 - recall: 5.4352e-04 - val_accuracy: 0.9934 - val_auc: 0.8163 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 55/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8072 - f1_score: 1.7895e-04 - loss: 0.0335 - precision: 0.1184 - recall: 8.9543e-05 - val_accuracy: 0.9934 - val_auc: 0.8168 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 56/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8131 - f1_score: 0.0000e+00 - loss: 0.0332 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8194 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 57/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - auc: 0.8154 - f1_score: 1.3595e-05 - loss: 0.0339 - precision: 0.0170 - recall: 6.8001e-06 - val_accuracy: 0.9934 - val_auc: 0.8202 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 58/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8138 - f1_score: 2.9025e-04 - loss: 0.0334 - precision: 0.0887 - recall: 1.4537e-04 - val_accuracy: 0.9934 - val_auc: 0.8168 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 59/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.8119 - f1_score: 3.2082e-05 - loss: 0.0336 - precision: 0.0783 - recall: 1.6044e-05 - val_accuracy: 0.9934 - val_auc: 0.8195 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 60/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - auc: 0.8112 - f1_score: 3.9937e-05 - loss: 0.0326 - precision: 0.0322 - recall: 1.9981e-05 - val_accuracy: 0.9934 - val_auc: 0.8222 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 61/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - auc: 0.8147 - f1_score: 0.0022 - loss: 0.0326 - precision: 0.6233 - recall: 0.0011 - val_accuracy: 0.9934 - val_auc: 0.8220 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 62/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - auc: 0.8125 - f1_score: 2.0504e-04 - loss: 0.0327 - precision: 0.1495 - recall: 1.0260e-04 - val_accuracy: 0.9934 - val_auc: 0.8196 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 63/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8160 - f1_score: 0.0000e+00 - loss: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8227 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 64/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8151 - f1_score: 0.0000e+00 - loss: 0.0335 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8165 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 65/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8114 - f1_score: 4.7585e-04 - loss: 0.0335 - precision: 0.5187 - recall: 2.3805e-04 - val_accuracy: 0.9934 - val_auc: 0.8167 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 66/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8191 - f1_score: 0.0011 - loss: 0.0330 - precision: 0.3072 - recall: 5.6353e-04 - val_accuracy: 0.9934 - val_auc: 0.8207 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 67/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8131 - f1_score: 3.7742e-04 - loss: 0.0331 - precision: 0.2820 - recall: 1.8884e-04 - val_accuracy: 0.9934 - val_auc: 0.8155 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 68/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9935 - auc: 0.8132 - f1_score: 0.0000e+00 - loss: 0.0332 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8148 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 69/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - auc: 0.8101 - f1_score: 0.0000e+00 - loss: 0.0326 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8128 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 70/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8155 - f1_score: 0.0013 - loss: 0.0331 - precision: 0.6295 - recall: 6.3873e-04 - val_accuracy: 0.9934 - val_auc: 0.8139 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 71/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8180 - f1_score: 0.0011 - loss: 0.0330 - precision: 0.5659 - recall: 5.7280e-04 - val_accuracy: 0.9934 - val_auc: 0.8201 - val_f1_score: 0.0000e+00 - val_loss: 0.0336 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 72/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - auc: 0.8147 - f1_score: 3.2231e-04 - loss: 0.0334 - precision: 0.1752 - recall: 1.6131e-04 - val_accuracy: 0.9934 - val_auc: 0.8214 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 73/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.8122 - f1_score: 0.0018 - loss: 0.0337 - precision: 0.4218 - recall: 8.8373e-04 - val_accuracy: 0.9934 - val_auc: 0.8217 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 74/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8157 - f1_score: 7.6718e-04 - loss: 0.0329 - precision: 0.3585 - recall: 3.8408e-04 - val_accuracy: 0.9934 - val_auc: 0.8153 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 75/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - auc: 0.8149 - f1_score: 4.1518e-04 - loss: 0.0329 - precision: 0.3094 - recall: 2.0774e-04 - val_accuracy: 0.9934 - val_auc: 0.8175 - val_f1_score: 0.0000e+00 - val_loss: 0.0336 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 76/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - auc: 0.8188 - f1_score: 5.3636e-04 - loss: 0.0327 - precision: 0.4357 - recall: 2.6836e-04 - val_accuracy: 0.9934 - val_auc: 0.8157 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 77/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.8190 - f1_score: 0.0000e+00 - loss: 0.0335 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9934 - val_auc: 0.8178 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 78/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - auc: 0.8201 - f1_score: 6.0688e-04 - loss: 0.0330 - precision: 0.1961 - recall: 3.0391e-04 - val_accuracy: 0.9934 - val_auc: 0.8200 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 79/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - auc: 0.8207 - f1_score: 0.0013 - loss: 0.0328 - precision: 0.4688 - recall: 6.4458e-04 - val_accuracy: 0.9934 - val_auc: 0.8190 - val_f1_score: 0.0000e+00 - val_loss: 0.0337 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 80/80
# 382/382 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - auc: 0.8242 - f1_score: 6.9855e-04 - loss: 0.0333 - precision: 0.4839 - recall: 3.4954e-04 - val_accuracy: 0.9934 - val_auc: 0.8187 - val_f1_score: 0.0000e+00 - val_loss: 0.0338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# 29697/29697 ━━━━━━━━━━━━━━━━━━━━ 31s 1ms/step
# Precision: 0.0
# Recall:    0.0
# F1 Score:  0.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  A2 (Injury)       0.50      1.00      0.67    475146
#   A1 (Fatal)       0.00      0.00      0.00    475146
#
#     accuracy                           0.50    950292
#    macro avg       0.25      0.50      0.33    950292
# weighted avg       0.25      0.50      0.33    950292
# /home/luluboy/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/luluboy/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/luluboy/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/luluboy/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# 1. Compute the confusion matrix
cm = confusion_matrix(y_test, pred_labels)

# 2. Create a display object,  passing in class names label=0 -> A2, label=1 -> A1
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=["A2", "A1"])

# 3. Plot the confusion matrix
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix: A2 vs. A1")
plt.show()

# %%
# Plotting loss
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()

# Plotting accuracy (ensure you have added an accuracy metric in model.compile)
if 'accuracy' in history.history:
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Model Accuracy')
    plt.legend()
else:
    print("Accuracy metric not found. Consider adding tf.keras.metrics.BinaryAccuracy(name='accuracy') to model.compile.")

plt.tight_layout()
plt.show()

# %%
print(y_test.shape)
# Out:
# (950292,)
