# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.utils import class_weight
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import backend as K

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from imblearn.over_sampling import RandomOverSampler
from collections import Counter

# %%
def load_year_data(year, file_type):
    # file_type should be 'A1' or 'A2'
    path = f"deprecated/dataset/{file_type}/{year}_{file_type}_cleaned.csv"
    df = pd.read_csv(path)
    # Assign labels: 1 for A1 (fatal), 0 for A2 (injury)
    df["label"] = 1 if file_type == "A1" else 0
    return df

# %%
train_years = ["108", "109", "110", "111", "112"]

train_dfs_A1 = [load_year_data(year, "A1") for year in train_years]
train_dfs_A2 = [load_year_data(year, "A2") for year in train_years]

df_train = pd.concat(train_dfs_A1 + train_dfs_A2, ignore_index=True)

df_a1_test = load_year_data("113", "A1")
df_a2_test = load_year_data("113", "A2")

df_a1_test["label"] = 1
df_a2_test["label"] = 0

# Combine into one DataFrame for testing
df_test = pd.concat([df_a1_test, df_a2_test], ignore_index=True)

# %%
categorical_cols = [
    "weather",
    "lighting",
    "road_condition",
    "traffic_signal",
    "vehicle_type",
    "gender",
    "protective_equipment"
]
numeric_cols = ["speed_limit", "age"]

# Drop rows with missing critical features in both training and testing sets
df_train.dropna(subset=categorical_cols + numeric_cols + ["label"], inplace=True)
df_test.dropna(subset=categorical_cols + numeric_cols + ["label"], inplace=True)

# Since the categorical columns are already numeric (0~n), we do not need to convert them.
# If needed, you can cast them to the proper dtype:
df_train[categorical_cols] = df_train[categorical_cols].astype(int)
df_test[categorical_cols] = df_test[categorical_cols].astype(int)

# Define features X and target y for training and testing
X_train = df_train[categorical_cols + numeric_cols]
y_train = df_train["label"]

X_test = df_test[categorical_cols + numeric_cols]
y_test = df_test["label"]

# %%
# Print original class distribution
print("Original distribution:", Counter(y_train))

# Initialize SMOTE and oversample the training data
ros = RandomOverSampler(sampling_strategy='minority')
X_train, y_train = ros.fit_resample(X_train, y_train)
X_test, y_test = ros.fit_resample(X_test, y_test)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Check the new class distribution
print("Resampled distribution:", Counter(y_train))
# Out:
# Original distribution: Counter({0: 810425, 1: 5139})
# Resampled distribution: Counter({1: 810425, 0: 810425})

# %%
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', threshold=0.5, **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.threshold = threshold
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.false_positives = self.add_weight(name='fp', initializer='zeros')
        self.false_negatives = self.add_weight(name='fn', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Convert probabilities to binary predictions
        y_pred = tf.cast(tf.greater(y_pred, self.threshold), tf.float32)
        y_true = tf.cast(y_true, tf.float32)

        tp = tf.reduce_sum(y_true * y_pred)
        fp = tf.reduce_sum((1 - y_true) * y_pred)
        fn = tf.reduce_sum(y_true * (1 - y_pred))

        self.true_positives.assign_add(tp)
        self.false_positives.assign_add(fp)
        self.false_negatives.assign_add(fn)

    def result(self):
        precision = self.true_positives / (self.true_positives + self.false_positives + K.epsilon())
        recall = self.true_positives / (self.true_positives + self.false_negatives + K.epsilon())
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.true_positives.assign(0)
        self.false_positives.assign(0)
        self.false_negatives.assign(0)

# %%
# ------------------------------------------------
# Build a TensorFlow (Keras) Model
# ------------------------------------------------
model = tf.keras.Sequential([
    # Input layer
    layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # First hidden layer with 128 units
    layers.Dense(128, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # Second hidden layer with 64 units
    layers.Dense(64, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # Third hidden layer with 32 units
    layers.Dense(32, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    # Fourth hidden layer with 16 units
    layers.Dense(16, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    # Output layer for binary classification
    layers.Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=[
        # "Accuracy"
        tf.keras.metrics.BinaryAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        F1Score(name='f1_score'),
        tf.keras.metrics.AUC(name='auc', num_thresholds=200)
    ]
)

# ------------------------------------------------
# Train Model with Class Weights using all 108 data for training
# ------------------------------------------------
history = model.fit(
    X_train, y_train,
    epochs=80,
    batch_size=2048,
    validation_split=0.3,
    verbose=1
)

# ------------------------------------------------
# Evaluate on Test Data from 109 files
# ------------------------------------------------
pred_probs = model.predict(X_test).ravel()
pred_labels = (pred_probs > 0.5).astype(int)

precision = precision_score(y_test, pred_labels)
recall = recall_score(y_test, pred_labels)
f1 = f1_score(y_test, pred_labels)

print("Precision:", precision)
print("Recall:   ", recall)
print("F1 Score: ", f1)

# Optional: detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, pred_labels, target_names=["A2 (Injury)", "A1 (Fatal)"]))
# Out:
# Epoch 1/80
# /home/luluboy/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.6770 - auc: 0.6572 - f1_score: 0.4189 - loss: 0.6286 - precision: 0.4495 - recall: 0.4097 - val_accuracy: 0.2551 - val_auc: 0.0000e+00 - val_f1_score: 0.4065 - val_loss: 1.0787 - val_precision: 1.0000 - val_recall: 0.2551
# Epoch 2/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7485 - auc: 0.7356 - f1_score: 0.4001 - loss: 0.5248 - precision: 0.6262 - recall: 0.2941 - val_accuracy: 0.3516 - val_auc: 0.0000e+00 - val_f1_score: 0.5203 - val_loss: 1.0589 - val_precision: 1.0000 - val_recall: 0.3516
# Epoch 3/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7583 - auc: 0.7515 - f1_score: 0.4541 - loss: 0.5120 - precision: 0.6390 - recall: 0.3523 - val_accuracy: 0.3779 - val_auc: 0.0000e+00 - val_f1_score: 0.5485 - val_loss: 1.0443 - val_precision: 1.0000 - val_recall: 0.3779
# Epoch 4/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7630 - auc: 0.7605 - f1_score: 0.4770 - loss: 0.5052 - precision: 0.6466 - recall: 0.3780 - val_accuracy: 0.3823 - val_auc: 0.0000e+00 - val_f1_score: 0.5531 - val_loss: 1.0362 - val_precision: 1.0000 - val_recall: 0.3823
# Epoch 5/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7661 - auc: 0.7639 - f1_score: 0.4905 - loss: 0.5019 - precision: 0.6501 - recall: 0.3938 - val_accuracy: 0.3974 - val_auc: 0.0000e+00 - val_f1_score: 0.5688 - val_loss: 1.0377 - val_precision: 1.0000 - val_recall: 0.3974
# Epoch 6/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7682 - auc: 0.7668 - f1_score: 0.4942 - loss: 0.4989 - precision: 0.6526 - recall: 0.3977 - val_accuracy: 0.3915 - val_auc: 0.0000e+00 - val_f1_score: 0.5627 - val_loss: 1.0342 - val_precision: 1.0000 - val_recall: 0.3915
# Epoch 7/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7683 - auc: 0.7696 - f1_score: 0.4965 - loss: 0.4974 - precision: 0.6556 - recall: 0.3996 - val_accuracy: 0.3874 - val_auc: 0.0000e+00 - val_f1_score: 0.5584 - val_loss: 1.0371 - val_precision: 1.0000 - val_recall: 0.3874
# Epoch 8/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7703 - auc: 0.7717 - f1_score: 0.4968 - loss: 0.4951 - precision: 0.6631 - recall: 0.3973 - val_accuracy: 0.3940 - val_auc: 0.0000e+00 - val_f1_score: 0.5653 - val_loss: 1.0298 - val_precision: 1.0000 - val_recall: 0.3940
# Epoch 9/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7717 - auc: 0.7742 - f1_score: 0.5041 - loss: 0.4933 - precision: 0.6643 - recall: 0.4061 - val_accuracy: 0.3902 - val_auc: 0.0000e+00 - val_f1_score: 0.5614 - val_loss: 1.0121 - val_precision: 1.0000 - val_recall: 0.3902
# Epoch 10/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7722 - auc: 0.7755 - f1_score: 0.5021 - loss: 0.4918 - precision: 0.6674 - recall: 0.4025 - val_accuracy: 0.3891 - val_auc: 0.0000e+00 - val_f1_score: 0.5602 - val_loss: 1.0141 - val_precision: 1.0000 - val_recall: 0.3891
# Epoch 11/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7736 - auc: 0.7779 - f1_score: 0.5022 - loss: 0.4896 - precision: 0.6723 - recall: 0.4008 - val_accuracy: 0.3915 - val_auc: 0.0000e+00 - val_f1_score: 0.5627 - val_loss: 1.0364 - val_precision: 1.0000 - val_recall: 0.3915
# Epoch 12/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7739 - auc: 0.7796 - f1_score: 0.5092 - loss: 0.4886 - precision: 0.6695 - recall: 0.4109 - val_accuracy: 0.3971 - val_auc: 0.0000e+00 - val_f1_score: 0.5685 - val_loss: 1.0226 - val_precision: 1.0000 - val_recall: 0.3971
# Epoch 13/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7744 - auc: 0.7805 - f1_score: 0.5129 - loss: 0.4882 - precision: 0.6721 - recall: 0.4147 - val_accuracy: 0.4072 - val_auc: 0.0000e+00 - val_f1_score: 0.5788 - val_loss: 0.9973 - val_precision: 1.0000 - val_recall: 0.4072
# Epoch 14/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7751 - auc: 0.7816 - f1_score: 0.5103 - loss: 0.4865 - precision: 0.6723 - recall: 0.4112 - val_accuracy: 0.4020 - val_auc: 0.0000e+00 - val_f1_score: 0.5735 - val_loss: 1.0000 - val_precision: 1.0000 - val_recall: 0.4020
# Epoch 15/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7754 - auc: 0.7826 - f1_score: 0.5150 - loss: 0.4860 - precision: 0.6725 - recall: 0.4173 - val_accuracy: 0.3993 - val_auc: 0.0000e+00 - val_f1_score: 0.5707 - val_loss: 0.9949 - val_precision: 1.0000 - val_recall: 0.3993
# Epoch 16/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7758 - auc: 0.7848 - f1_score: 0.5169 - loss: 0.4844 - precision: 0.6727 - recall: 0.4197 - val_accuracy: 0.4054 - val_auc: 0.0000e+00 - val_f1_score: 0.5769 - val_loss: 0.9953 - val_precision: 1.0000 - val_recall: 0.4054
# Epoch 17/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7763 - auc: 0.7848 - f1_score: 0.5177 - loss: 0.4845 - precision: 0.6732 - recall: 0.4206 - val_accuracy: 0.4115 - val_auc: 0.0000e+00 - val_f1_score: 0.5831 - val_loss: 0.9939 - val_precision: 1.0000 - val_recall: 0.4115
# Epoch 18/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7757 - auc: 0.7847 - f1_score: 0.5157 - loss: 0.4843 - precision: 0.6727 - recall: 0.4182 - val_accuracy: 0.4044 - val_auc: 0.0000e+00 - val_f1_score: 0.5759 - val_loss: 0.9798 - val_precision: 1.0000 - val_recall: 0.4044
# Epoch 19/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7760 - auc: 0.7857 - f1_score: 0.5199 - loss: 0.4838 - precision: 0.6719 - recall: 0.4241 - val_accuracy: 0.4171 - val_auc: 0.0000e+00 - val_f1_score: 0.5887 - val_loss: 0.9825 - val_precision: 1.0000 - val_recall: 0.4171
# Epoch 20/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7780 - auc: 0.7876 - f1_score: 0.5228 - loss: 0.4814 - precision: 0.6764 - recall: 0.4261 - val_accuracy: 0.4165 - val_auc: 0.0000e+00 - val_f1_score: 0.5881 - val_loss: 0.9812 - val_precision: 1.0000 - val_recall: 0.4165
# Epoch 21/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7776 - auc: 0.7884 - f1_score: 0.5214 - loss: 0.4813 - precision: 0.6776 - recall: 0.4237 - val_accuracy: 0.4139 - val_auc: 0.0000e+00 - val_f1_score: 0.5855 - val_loss: 0.9815 - val_precision: 1.0000 - val_recall: 0.4139
# Epoch 22/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7769 - auc: 0.7867 - f1_score: 0.5211 - loss: 0.4826 - precision: 0.6744 - recall: 0.4247 - val_accuracy: 0.4230 - val_auc: 0.0000e+00 - val_f1_score: 0.5945 - val_loss: 0.9767 - val_precision: 1.0000 - val_recall: 0.4230
# Epoch 23/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7781 - auc: 0.7892 - f1_score: 0.5244 - loss: 0.4801 - precision: 0.6750 - recall: 0.4288 - val_accuracy: 0.4204 - val_auc: 0.0000e+00 - val_f1_score: 0.5920 - val_loss: 0.9839 - val_precision: 1.0000 - val_recall: 0.4204
# Epoch 24/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7795 - auc: 0.7910 - f1_score: 0.5288 - loss: 0.4782 - precision: 0.6767 - recall: 0.4339 - val_accuracy: 0.4349 - val_auc: 0.0000e+00 - val_f1_score: 0.6062 - val_loss: 0.9674 - val_precision: 1.0000 - val_recall: 0.4349
# Epoch 25/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7791 - auc: 0.7918 - f1_score: 0.5294 - loss: 0.4780 - precision: 0.6757 - recall: 0.4353 - val_accuracy: 0.4145 - val_auc: 0.0000e+00 - val_f1_score: 0.5861 - val_loss: 0.9574 - val_precision: 1.0000 - val_recall: 0.4145
# Epoch 26/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7778 - auc: 0.7891 - f1_score: 0.5189 - loss: 0.4807 - precision: 0.6803 - recall: 0.4195 - val_accuracy: 0.4066 - val_auc: 0.0000e+00 - val_f1_score: 0.5781 - val_loss: 0.9776 - val_precision: 1.0000 - val_recall: 0.4066
# Epoch 27/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7786 - auc: 0.7910 - f1_score: 0.5224 - loss: 0.4785 - precision: 0.6798 - recall: 0.4243 - val_accuracy: 0.4358 - val_auc: 0.0000e+00 - val_f1_score: 0.6071 - val_loss: 0.9625 - val_precision: 1.0000 - val_recall: 0.4358
# Epoch 28/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7795 - auc: 0.7923 - f1_score: 0.5302 - loss: 0.4776 - precision: 0.6766 - recall: 0.4359 - val_accuracy: 0.4353 - val_auc: 0.0000e+00 - val_f1_score: 0.6065 - val_loss: 0.9668 - val_precision: 1.0000 - val_recall: 0.4353
# Epoch 29/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7797 - auc: 0.7927 - f1_score: 0.5309 - loss: 0.4773 - precision: 0.6791 - recall: 0.4358 - val_accuracy: 0.4336 - val_auc: 0.0000e+00 - val_f1_score: 0.6049 - val_loss: 0.9650 - val_precision: 1.0000 - val_recall: 0.4336
# Epoch 30/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7793 - auc: 0.7924 - f1_score: 0.5290 - loss: 0.4775 - precision: 0.6779 - recall: 0.4337 - val_accuracy: 0.4002 - val_auc: 0.0000e+00 - val_f1_score: 0.5717 - val_loss: 0.9848 - val_precision: 1.0000 - val_recall: 0.4002
# Epoch 31/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7784 - auc: 0.7919 - f1_score: 0.5255 - loss: 0.4785 - precision: 0.6781 - recall: 0.4290 - val_accuracy: 0.4198 - val_auc: 0.0000e+00 - val_f1_score: 0.5913 - val_loss: 0.9672 - val_precision: 1.0000 - val_recall: 0.4198
# Epoch 32/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7791 - auc: 0.7934 - f1_score: 0.5269 - loss: 0.4769 - precision: 0.6795 - recall: 0.4302 - val_accuracy: 0.4342 - val_auc: 0.0000e+00 - val_f1_score: 0.6055 - val_loss: 0.9415 - val_precision: 1.0000 - val_recall: 0.4342
# Epoch 33/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7808 - auc: 0.7947 - f1_score: 0.5351 - loss: 0.4759 - precision: 0.6813 - recall: 0.4406 - val_accuracy: 0.4501 - val_auc: 0.0000e+00 - val_f1_score: 0.6208 - val_loss: 0.9503 - val_precision: 1.0000 - val_recall: 0.4501
# Epoch 34/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7801 - auc: 0.7948 - f1_score: 0.5321 - loss: 0.4759 - precision: 0.6803 - recall: 0.4369 - val_accuracy: 0.4454 - val_auc: 0.0000e+00 - val_f1_score: 0.6163 - val_loss: 0.9375 - val_precision: 1.0000 - val_recall: 0.4454
# Epoch 35/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7803 - auc: 0.7940 - f1_score: 0.5292 - loss: 0.4761 - precision: 0.6836 - recall: 0.4317 - val_accuracy: 0.4410 - val_auc: 0.0000e+00 - val_f1_score: 0.6121 - val_loss: 0.9546 - val_precision: 1.0000 - val_recall: 0.4410
# Epoch 36/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7791 - auc: 0.7920 - f1_score: 0.5243 - loss: 0.4777 - precision: 0.6806 - recall: 0.4264 - val_accuracy: 0.4389 - val_auc: 0.0000e+00 - val_f1_score: 0.6100 - val_loss: 0.9461 - val_precision: 1.0000 - val_recall: 0.4389
# Epoch 37/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7797 - auc: 0.7942 - f1_score: 0.5317 - loss: 0.4762 - precision: 0.6788 - recall: 0.4370 - val_accuracy: 0.4334 - val_auc: 0.0000e+00 - val_f1_score: 0.6047 - val_loss: 0.9486 - val_precision: 1.0000 - val_recall: 0.4334
# Epoch 38/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7804 - auc: 0.7954 - f1_score: 0.5311 - loss: 0.4754 - precision: 0.6841 - recall: 0.4341 - val_accuracy: 0.4317 - val_auc: 0.0000e+00 - val_f1_score: 0.6031 - val_loss: 0.9599 - val_precision: 1.0000 - val_recall: 0.4317
# Epoch 39/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - auc: 0.7961 - f1_score: 0.5329 - loss: 0.4741 - precision: 0.6823 - recall: 0.4372 - val_accuracy: 0.4418 - val_auc: 0.0000e+00 - val_f1_score: 0.6129 - val_loss: 0.9418 - val_precision: 1.0000 - val_recall: 0.4418
# Epoch 40/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7808 - auc: 0.7953 - f1_score: 0.5332 - loss: 0.4751 - precision: 0.6815 - recall: 0.4379 - val_accuracy: 0.4341 - val_auc: 0.0000e+00 - val_f1_score: 0.6054 - val_loss: 0.9575 - val_precision: 1.0000 - val_recall: 0.4341
# Epoch 41/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7804 - auc: 0.7954 - f1_score: 0.5308 - loss: 0.4748 - precision: 0.6808 - recall: 0.4350 - val_accuracy: 0.4671 - val_auc: 0.0000e+00 - val_f1_score: 0.6368 - val_loss: 0.9307 - val_precision: 1.0000 - val_recall: 0.4671
# Epoch 42/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7820 - auc: 0.7975 - f1_score: 0.5373 - loss: 0.4727 - precision: 0.6799 - recall: 0.4441 - val_accuracy: 0.4344 - val_auc: 0.0000e+00 - val_f1_score: 0.6057 - val_loss: 0.9513 - val_precision: 1.0000 - val_recall: 0.4344
# Epoch 43/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7809 - auc: 0.7967 - f1_score: 0.5346 - loss: 0.4740 - precision: 0.6819 - recall: 0.4396 - val_accuracy: 0.4214 - val_auc: 0.0000e+00 - val_f1_score: 0.5929 - val_loss: 0.9575 - val_precision: 1.0000 - val_recall: 0.4214
# Epoch 44/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7809 - auc: 0.7974 - f1_score: 0.5317 - loss: 0.4732 - precision: 0.6819 - recall: 0.4358 - val_accuracy: 0.4512 - val_auc: 0.0000e+00 - val_f1_score: 0.6218 - val_loss: 0.9472 - val_precision: 1.0000 - val_recall: 0.4512
# Epoch 45/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7815 - auc: 0.7976 - f1_score: 0.5364 - loss: 0.4732 - precision: 0.6820 - recall: 0.4420 - val_accuracy: 0.4431 - val_auc: 0.0000e+00 - val_f1_score: 0.6141 - val_loss: 0.9603 - val_precision: 1.0000 - val_recall: 0.4431
# Epoch 46/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7814 - auc: 0.7965 - f1_score: 0.5345 - loss: 0.4734 - precision: 0.6802 - recall: 0.4402 - val_accuracy: 0.4460 - val_auc: 0.0000e+00 - val_f1_score: 0.6169 - val_loss: 0.9400 - val_precision: 1.0000 - val_recall: 0.4460
# Epoch 47/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - auc: 0.7968 - f1_score: 0.5327 - loss: 0.4734 - precision: 0.6819 - recall: 0.4371 - val_accuracy: 0.4485 - val_auc: 0.0000e+00 - val_f1_score: 0.6193 - val_loss: 0.9384 - val_precision: 1.0000 - val_recall: 0.4485
# Epoch 48/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7818 - auc: 0.7981 - f1_score: 0.5363 - loss: 0.4724 - precision: 0.6817 - recall: 0.4420 - val_accuracy: 0.4363 - val_auc: 0.0000e+00 - val_f1_score: 0.6075 - val_loss: 0.9527 - val_precision: 1.0000 - val_recall: 0.4363
# Epoch 49/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7805 - auc: 0.7957 - f1_score: 0.5331 - loss: 0.4750 - precision: 0.6797 - recall: 0.4385 - val_accuracy: 0.4463 - val_auc: 0.0000e+00 - val_f1_score: 0.6172 - val_loss: 0.9288 - val_precision: 1.0000 - val_recall: 0.4463
# Epoch 50/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7806 - auc: 0.7977 - f1_score: 0.5345 - loss: 0.4731 - precision: 0.6786 - recall: 0.4409 - val_accuracy: 0.4310 - val_auc: 0.0000e+00 - val_f1_score: 0.6023 - val_loss: 0.9586 - val_precision: 1.0000 - val_recall: 0.4310
# Epoch 51/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7814 - auc: 0.7972 - f1_score: 0.5338 - loss: 0.4731 - precision: 0.6827 - recall: 0.4382 - val_accuracy: 0.4399 - val_auc: 0.0000e+00 - val_f1_score: 0.6110 - val_loss: 0.9557 - val_precision: 1.0000 - val_recall: 0.4399
# Epoch 52/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7822 - auc: 0.7990 - f1_score: 0.5384 - loss: 0.4714 - precision: 0.6818 - recall: 0.4449 - val_accuracy: 0.4598 - val_auc: 0.0000e+00 - val_f1_score: 0.6300 - val_loss: 0.9391 - val_precision: 1.0000 - val_recall: 0.4598
# Epoch 53/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7824 - auc: 0.7992 - f1_score: 0.5391 - loss: 0.4717 - precision: 0.6840 - recall: 0.4449 - val_accuracy: 0.4541 - val_auc: 0.0000e+00 - val_f1_score: 0.6246 - val_loss: 0.9376 - val_precision: 1.0000 - val_recall: 0.4541
# Epoch 54/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7805 - auc: 0.7972 - f1_score: 0.5343 - loss: 0.4736 - precision: 0.6812 - recall: 0.4395 - val_accuracy: 0.4377 - val_auc: 0.0000e+00 - val_f1_score: 0.6089 - val_loss: 0.9521 - val_precision: 1.0000 - val_recall: 0.4377
# Epoch 55/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7821 - auc: 0.7983 - f1_score: 0.5371 - loss: 0.4720 - precision: 0.6821 - recall: 0.4429 - val_accuracy: 0.4318 - val_auc: 0.0000e+00 - val_f1_score: 0.6031 - val_loss: 0.9701 - val_precision: 1.0000 - val_recall: 0.4318
# Epoch 56/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7818 - auc: 0.7992 - f1_score: 0.5377 - loss: 0.4713 - precision: 0.6816 - recall: 0.4440 - val_accuracy: 0.4528 - val_auc: 0.0000e+00 - val_f1_score: 0.6234 - val_loss: 0.9345 - val_precision: 1.0000 - val_recall: 0.4528
# Epoch 57/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7818 - auc: 0.7985 - f1_score: 0.5362 - loss: 0.4720 - precision: 0.6828 - recall: 0.4414 - val_accuracy: 0.4459 - val_auc: 0.0000e+00 - val_f1_score: 0.6167 - val_loss: 0.9420 - val_precision: 1.0000 - val_recall: 0.4459
# Epoch 58/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7833 - auc: 0.8008 - f1_score: 0.5377 - loss: 0.4692 - precision: 0.6838 - recall: 0.4430 - val_accuracy: 0.4434 - val_auc: 0.0000e+00 - val_f1_score: 0.6144 - val_loss: 0.9431 - val_precision: 1.0000 - val_recall: 0.4434
# Epoch 59/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7825 - auc: 0.8006 - f1_score: 0.5389 - loss: 0.4704 - precision: 0.6842 - recall: 0.4445 - val_accuracy: 0.4566 - val_auc: 0.0000e+00 - val_f1_score: 0.6269 - val_loss: 0.9302 - val_precision: 1.0000 - val_recall: 0.4566
# Epoch 60/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7826 - auc: 0.7997 - f1_score: 0.5388 - loss: 0.4706 - precision: 0.6831 - recall: 0.4448 - val_accuracy: 0.4703 - val_auc: 0.0000e+00 - val_f1_score: 0.6398 - val_loss: 0.9231 - val_precision: 1.0000 - val_recall: 0.4703
# Epoch 61/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7824 - auc: 0.8003 - f1_score: 0.5392 - loss: 0.4705 - precision: 0.6829 - recall: 0.4455 - val_accuracy: 0.4482 - val_auc: 0.0000e+00 - val_f1_score: 0.6190 - val_loss: 0.9312 - val_precision: 1.0000 - val_recall: 0.4482
# Epoch 62/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7813 - auc: 0.7967 - f1_score: 0.5362 - loss: 0.4732 - precision: 0.6789 - recall: 0.4431 - val_accuracy: 0.4510 - val_auc: 0.0000e+00 - val_f1_score: 0.6216 - val_loss: 0.9341 - val_precision: 1.0000 - val_recall: 0.4510
# Epoch 63/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7819 - auc: 0.7983 - f1_score: 0.5352 - loss: 0.4725 - precision: 0.6859 - recall: 0.4388 - val_accuracy: 0.4334 - val_auc: 0.0000e+00 - val_f1_score: 0.6047 - val_loss: 0.9474 - val_precision: 1.0000 - val_recall: 0.4334
# Epoch 64/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7823 - auc: 0.7987 - f1_score: 0.5357 - loss: 0.4719 - precision: 0.6862 - recall: 0.4393 - val_accuracy: 0.4322 - val_auc: 0.0000e+00 - val_f1_score: 0.6036 - val_loss: 0.9405 - val_precision: 1.0000 - val_recall: 0.4322
# Epoch 65/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7813 - auc: 0.7975 - f1_score: 0.5320 - loss: 0.4731 - precision: 0.6851 - recall: 0.4349 - val_accuracy: 0.4592 - val_auc: 0.0000e+00 - val_f1_score: 0.6294 - val_loss: 0.9369 - val_precision: 1.0000 - val_recall: 0.4592
# Epoch 66/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7821 - auc: 0.7998 - f1_score: 0.5362 - loss: 0.4709 - precision: 0.6842 - recall: 0.4409 - val_accuracy: 0.4569 - val_auc: 0.0000e+00 - val_f1_score: 0.6273 - val_loss: 0.9394 - val_precision: 1.0000 - val_recall: 0.4569
# Epoch 67/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7825 - auc: 0.8002 - f1_score: 0.5385 - loss: 0.4704 - precision: 0.6831 - recall: 0.4445 - val_accuracy: 0.4750 - val_auc: 0.0000e+00 - val_f1_score: 0.6441 - val_loss: 0.9146 - val_precision: 1.0000 - val_recall: 0.4750
# Epoch 68/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7823 - auc: 0.8002 - f1_score: 0.5401 - loss: 0.4704 - precision: 0.6814 - recall: 0.4473 - val_accuracy: 0.4484 - val_auc: 0.0000e+00 - val_f1_score: 0.6192 - val_loss: 0.9437 - val_precision: 1.0000 - val_recall: 0.4484
# Epoch 69/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7826 - auc: 0.8004 - f1_score: 0.5400 - loss: 0.4704 - precision: 0.6822 - recall: 0.4469 - val_accuracy: 0.4652 - val_auc: 0.0000e+00 - val_f1_score: 0.6350 - val_loss: 0.9203 - val_precision: 1.0000 - val_recall: 0.4652
# Epoch 70/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7832 - auc: 0.8013 - f1_score: 0.5392 - loss: 0.4694 - precision: 0.6863 - recall: 0.4441 - val_accuracy: 0.4647 - val_auc: 0.0000e+00 - val_f1_score: 0.6346 - val_loss: 0.9284 - val_precision: 1.0000 - val_recall: 0.4647
# Epoch 71/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7823 - auc: 0.8004 - f1_score: 0.5388 - loss: 0.4703 - precision: 0.6830 - recall: 0.4449 - val_accuracy: 0.4731 - val_auc: 0.0000e+00 - val_f1_score: 0.6423 - val_loss: 0.9195 - val_precision: 1.0000 - val_recall: 0.4731
# Epoch 72/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7835 - auc: 0.8025 - f1_score: 0.5454 - loss: 0.4682 - precision: 0.6806 - recall: 0.4550 - val_accuracy: 0.4489 - val_auc: 0.0000e+00 - val_f1_score: 0.6197 - val_loss: 0.9558 - val_precision: 1.0000 - val_recall: 0.4489
# Epoch 73/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7828 - auc: 0.7999 - f1_score: 0.5382 - loss: 0.4709 - precision: 0.6859 - recall: 0.4428 - val_accuracy: 0.4527 - val_auc: 0.0000e+00 - val_f1_score: 0.6232 - val_loss: 0.9421 - val_precision: 1.0000 - val_recall: 0.4527
# Epoch 74/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7832 - auc: 0.8003 - f1_score: 0.5407 - loss: 0.4703 - precision: 0.6839 - recall: 0.4472 - val_accuracy: 0.4419 - val_auc: 0.0000e+00 - val_f1_score: 0.6129 - val_loss: 0.9406 - val_precision: 1.0000 - val_recall: 0.4419
# Epoch 75/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7840 - auc: 0.8027 - f1_score: 0.5409 - loss: 0.4677 - precision: 0.6858 - recall: 0.4465 - val_accuracy: 0.4583 - val_auc: 0.0000e+00 - val_f1_score: 0.6285 - val_loss: 0.9276 - val_precision: 1.0000 - val_recall: 0.4583
# Epoch 76/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7820 - auc: 0.7996 - f1_score: 0.5379 - loss: 0.4709 - precision: 0.6805 - recall: 0.4447 - val_accuracy: 0.4675 - val_auc: 0.0000e+00 - val_f1_score: 0.6372 - val_loss: 0.9192 - val_precision: 1.0000 - val_recall: 0.4675
# Epoch 77/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7829 - auc: 0.7997 - f1_score: 0.5407 - loss: 0.4706 - precision: 0.6847 - recall: 0.4467 - val_accuracy: 0.4580 - val_auc: 0.0000e+00 - val_f1_score: 0.6282 - val_loss: 0.9355 - val_precision: 1.0000 - val_recall: 0.4580
# Epoch 78/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7840 - auc: 0.8017 - f1_score: 0.5410 - loss: 0.4686 - precision: 0.6866 - recall: 0.4464 - val_accuracy: 0.4727 - val_auc: 0.0000e+00 - val_f1_score: 0.6419 - val_loss: 0.9110 - val_precision: 1.0000 - val_recall: 0.4727
# Epoch 79/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7837 - auc: 0.8020 - f1_score: 0.5444 - loss: 0.4688 - precision: 0.6844 - recall: 0.4519 - val_accuracy: 0.4672 - val_auc: 0.0000e+00 - val_f1_score: 0.6369 - val_loss: 0.9185 - val_precision: 1.0000 - val_recall: 0.4672
# Epoch 80/80
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7826 - auc: 0.8001 - f1_score: 0.5400 - loss: 0.4708 - precision: 0.6829 - recall: 0.4465 - val_accuracy: 0.4562 - val_auc: 0.0000e+00 - val_f1_score: 0.6265 - val_loss: 0.9407 - val_precision: 1.0000 - val_recall: 0.4562
# 52002/52002 ━━━━━━━━━━━━━━━━━━━━ 57s 1ms/step
# Precision: 0.846545042224441
# Recall:    0.2404824889816218
# F1 Score:  0.37456136656136657
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  A2 (Injury)       0.56      0.96      0.70    832019
#   A1 (Fatal)       0.85      0.24      0.37    832019
#
#     accuracy                           0.60   1664038
#    macro avg       0.70      0.60      0.54   1664038
# weighted avg       0.70      0.60      0.54   1664038

# %%
# 1. Compute the confusion matrix
cm = confusion_matrix(y_test, pred_labels)

# 2. Create a display object, optionally passing in class names
#    Here we assume label=0 -> A2, label=1 -> A1
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=["A2", "A1"])

# 3. Plot the confusion matrix
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix: A2 vs. A1")
plt.show()
